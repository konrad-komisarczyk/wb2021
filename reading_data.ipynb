# %%
import pandas as pd
import numpy as np

# %%
french_data = pd.read_excel("raw_data/Outcomerea_FR.xlsx")
chinese_data = pd.read_excel("raw_data/Tongji_375_CN.xlsx")
holland_data = pd.read_excel("raw_data/St_Antonius_NL.xlsx")
chinese_data_2 = pd.read_excel("raw_data/Tongji_375_CN.xlsx")

# %%
chinese_data.head()
# Out:
#    PATIENT_ID             RE_DATE  age  gender      Admission time  \
# 0         1.0 2020-01-31 01:09:00   73       1 2020-01-30 22:12:47
# 1         NaN 2020-01-31 01:25:00   73       1 2020-01-30 22:12:47
# 2         NaN 2020-01-31 01:44:00   73       1 2020-01-30 22:12:47
# 3         NaN 2020-01-31 01:45:00   73       1 2020-01-30 22:12:47
# 4         NaN 2020-01-31 01:56:00   73       1 2020-01-30 22:12:47
#
#        Discharge time  outcome  Hypersensitive cardiac troponinI  hemoglobin  \
# 0 2020-02-17 12:40:09        0                               NaN         NaN
# 1 2020-02-17 12:40:09        0                               NaN       136.0
# 2 2020-02-17 12:40:09        0                               NaN         NaN
# 3 2020-02-17 12:40:09        0                               NaN         NaN
# 4 2020-02-17 12:40:09        0                              19.9         NaN
#
#    Serum chloride  ...  mean corpuscular hemoglobin   \
# ...

# %%
chinese_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 81 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     375 non-null    float64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
# ...

# %%
chinese_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 81 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     375 non-null    float64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
# ...

# %%
french_data.head()
# Out:
#    id  HR_min  HR_max  SBP_min  SBP_max  DBP_min  DBP_max  SAPSII  RR  GCS  \
# 0  49      61      94       93      190       66      132      27  28   15
# 1  52      85     105       90      107       56       73      31  28   15
# 2  55      81     170      101      154       48       66      54  20   15
# 3  56      79     124      105      132       40       65      27   .   15
# 4  58      77      90      110      166       54       80      47   .   15
#
#    ... ldh_j1  ldh_j2  ldh_j3  ldh_j4 ldh_j5  L_pourc_J1  L_pourc_J2  \
# 0  ...      .  465.00  457.00  412.00  362.0     25.0000           .
# 1  ...  652.0  900.00       .       .      .           .     13.3333
# 2  ...  498.0  505.00       .       .  596.0           .           .
# 3  ...  568.0       .       .       .      .      4.1667           .
# 4  ...  455.0  450.00  535.00       .  497.0     10.0000           .
#
#    L_pourc_J3  L_pourc_J4  L_pourc_J5
# 0           .           .           .
# ...

# %%
french_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  178 non-null    int64
#  1   HR_min              178 non-null    int64
#  2   HR_max              178 non-null    int64
#  3   SBP_min             178 non-null    int64
#  4   SBP_max             178 non-null    int64
#  5   DBP_min             178 non-null    int64
#  6   DBP_max             178 non-null    int64
#  7   SAPSII              178 non-null    int64
#  8   RR                  178 non-null    object
#  9   GCS                 178 non-null    int64
#  10  date_hospital_admi  178 non-null    datetime64[ns]
#  11  date_hospital_end   178 non-null    object
#  12  date_ICU_admi       178 non-null    datetime64[ns]
#  13  date_ICU_end        178 non-null    datetime64[ns]
#  14  date_death          178 non-null    object
# ...

# %%
french_data[french_data == "."].count()
# Out:
# id                      0
# HR_min                  0
# HR_max                  0
# SBP_min                 0
# SBP_max                 0
# DBP_min                 0
# DBP_max                 0
# SAPSII                  0
# RR                     14
# GCS                     0
# date_hospital_admi      0
# date_hospital_end      30
# date_ICU_admi           0
# date_ICU_end            0
# date_death            116
# time_smyp_ICUadmi       0
# male                    0
# ICU_LOS                 0
# ICU_DC                  0
# time_hosp_ICU           0
# Age                     0
# Death_D28               0
# Death_D7                0
# ddimere_J1             78
# ddimere_J2             69
# ddimere_J3             55
# ddimere_J4             69
# ddimere_J5             71
# crp_J1                 40
# crp_J2                 49
# crp_J3                 53
# crp_J4                 64
# crp_J5                 71
# ldh_j1                 18
# ldh_j2                 42
# ...

# %%
french_data = french_data.replace('.', np.nan)

# %%
french_data.head()
# Out:
#    id  HR_min  HR_max  SBP_min  SBP_max  DBP_min  DBP_max  SAPSII    RR  GCS  \
# 0  49      61      94       93      190       66      132      27  28.0   15
# 1  52      85     105       90      107       56       73      31  28.0   15
# 2  55      81     170      101      154       48       66      54  20.0   15
# 3  56      79     124      105      132       40       65      27   NaN   15
# 4  58      77      90      110      166       54       80      47   NaN   15
#
#    ... ldh_j1  ldh_j2  ldh_j3  ldh_j4 ldh_j5  L_pourc_J1  L_pourc_J2  \
# 0  ...    NaN  465.00  457.00  412.00  362.0     25.0000         NaN
# 1  ...  652.0  900.00     NaN     NaN    NaN         NaN     13.3333
# 2  ...  498.0  505.00     NaN     NaN  596.0         NaN         NaN
# 3  ...  568.0     NaN     NaN     NaN    NaN      4.1667         NaN
# 4  ...  455.0  450.00  535.00     NaN  497.0     10.0000         NaN
#
#    L_pourc_J3  L_pourc_J4  L_pourc_J5
# 0         NaN         NaN         NaN
# ...

# %%
#Te dane chińskie (?) są bardzo wybrakowane, nwm czy coś z nich wyłuskamy
#Te francuskie nie są opisane i nie wiem co jest, a co nie jest potrzebna
#Holenderskie są git

# %%
holland_data.head()
# Out:
#    Age  Gender Date of presentation emergency room    Date of admission  \
# 0   73    Male                          2020-03-19  2020-03-19 00:00:00
# 1   60  Female                          2020-03-18  2020-03-18 00:00:00
# 2   44  Female                          2020-03-20  2020-03-20 00:00:00
# 3   58    Male                          2020-03-20  2020-03-20 00:00:00
# 4   66    Male                          2020-03-20  2020-03-20 00:00:00
#
#      Date of discharge Admission to ICU Survival/death Date of death  \
# 0  2020-05-26 00:00:00              Yes          Alive           NaT
# 1  2020-03-22 00:00:00               No          Alive           NaT
# 2  2020-03-24 00:00:00               No          Alive           NaT
# 3  2020-03-23 00:00:00              Yes          Alive           NaT
# 4  2020-03-25 00:00:00               No          Alive           NaT
#
#    Days from admission to death Date blood analysis   LD  CRP  Lymphocytes  \
# ...

# %%
holland_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Age                                  305 non-null    int64
#  1   Gender                               305 non-null    object
#  2   Date of presentation emergency room  305 non-null    datetime64[ns]
#  3   Date of admission                    305 non-null    object
#  4   Date of discharge                    305 non-null    object
#  5   Admission to ICU                     305 non-null    object
#  6   Survival/death                       305 non-null    object
#  7   Date of death                        61 non-null     datetime64[ns]
#  8   Days from admission to death         62 non-null     float64
#  9   Date blood analysis                  305 non-null    datetime64[ns]
# ...
